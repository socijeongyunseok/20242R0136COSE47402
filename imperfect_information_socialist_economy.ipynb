# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
# !pip install torch_geometric
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.11.9)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2024.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.66.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->torch_geometric) (4.12.2)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.6 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1

# %%
from torch_geometric.nn import GCNConv
from torch.distributions import Normal
import pandas as pd

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.autograd.set_detect_anomaly(False)

###############################################################
# Hyperparameters (Inputs)
###############################################################
NUM_REGIONS = 5
HIDDEN_DIM = 32
LATENT_DIM = 8
TIME_STEPS = 10   # fewer steps
EPOCHS = 500         # fewer epochs for demonstration
EPISODES_PER_EPOCH = 2
LEARNING_RATE = 1e-6
GAMMA = 0.99
bar_U = 0.0
MAX_RESOURCE = 1000.0

# Production parameters
alpha = 0.3
beta = 0.4
delta_k = 0.05
a = 0.01   # cost coefficient

# Shock
std_Z = 0.01

# Graph edges (chain)
GRAPH_EDGES = [(i, i+1) for i in range(NUM_REGIONS-1)]
edge_index = torch.tensor(GRAPH_EDGES, dtype=torch.long).t().contiguous().to(device)

# Loss Weights
WEIGHT_VAE = 1.0
WEIGHT_IC = 1.0
WEIGHT_IR = 1.0
WEIGHT_OSTROM = 1.0
WEIGHT_RESOURCE = 1.0
WEIGHT_POLICY = 1.0

# Monetary Policy Parameters

pi_star = 0.02  # target inflation
Y_star = 500.0  # arbitrary target output
phi_pi = 10.0
phi_y = 0.1

# Introduce population per region (just as a parameter, not fully utilized yet)
population = torch.tensor([100., 150., 120., 200., 180.], device=device)

# %%
# Functions
def g_func(R):
    K = MAX_RESOURCE
    r = 0.1
    return r * R * (1 - R/K)

def production(k_i, l_i, theta_i, Z):
    k_i = torch.clamp(k_i, min=1e-6)
    l_i = torch.clamp(l_i, min=1e-6)
    theta_i = torch.clamp(theta_i, min=0.1)
    return torch.exp(Z) * (theta_i**alpha) * (k_i**beta) * (l_i**(1-beta))

def utility_function(c_i, theta_i):
    c_i = torch.clamp(c_i, min=0)
    theta_i = torch.clamp(theta_i, min=0.1)
    return torch.sqrt(c_i * theta_i) - a * c_i

def resource_update(R, c_vector, x_vector):
    return R + g_func(R) - c_vector.sum() - x_vector.sum()

def capital_update(k_i, x_i):
    return (1 - delta_k)*k_i + x_i

def incentive_compatibility_loss(true_types, allocations):
    mean_type = true_types.mean()
    U_truthful = torch.tensor(0.0, device=device)
    U_deviant = torch.tensor(0.0, device=device)
    for i in range(NUM_REGIONS):
        U_truthful += utility_function(allocations[i], true_types[i])
        U_deviant += utility_function(allocations[i], mean_type)
    penalty = torch.clamp(U_deviant - U_truthful, min=0)
    return penalty

def individual_rationality_loss(avg_utilities, bar_U=bar_U):
    diff = avg_utilities - bar_U
    penalty = torch.mean(torch.clamp(-diff, min=0))
    return penalty

def ostrom_cooperation_loss(allocations_history):
    if len(allocations_history)<2:
        return torch.tensor(0.0, device=device)
    alloc_tensor = torch.stack(allocations_history, dim=0)
    var = alloc_tensor.var(dim=0).mean()
    return var

def resource_constraint_loss(R, c_alloc, x_alloc):
    cap = R + g_func(R)*10.0
    excess = torch.clamp(c_alloc.sum() + x_alloc.sum() - cap, min=0)
    return excess**2

###############################################################
# Models
###############################################################

class VAETypeInference(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(VAETypeInference, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, HIDDEN_DIM),
            nn.ReLU(),
            nn.Linear(HIDDEN_DIM, 2*latent_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, HIDDEN_DIM),
            nn.ReLU(),
            nn.Linear(HIDDEN_DIM, input_dim)
        )
        self.latent_dim = latent_dim

    def forward(self, x):
        stats = self.encoder(x)
        mu, logvar = stats[:,:self.latent_dim], stats[:,self.latent_dim:]
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        z = mu + eps*std
        recon = self.decoder(z)
        return recon, mu, logvar, z

    def loss_function(self, recon, x, mu, logvar):
        recon_loss = F.mse_loss(recon, x, reduction='mean')
        kl = -0.5*torch.mean(1+logvar - mu.pow(2)-logvar.exp())
        return recon_loss + kl

class DemandForecastModel(nn.Module):
    def __init__(self, input_dim=10, hidden_dim=16, num_layers=1):
        super(DemandForecastModel, self).__init__()
        self.rnn = nn.GRU(input_dim, hidden_dim, num_layers=num_layers, batch_first=True)
        self.out = nn.Linear(hidden_dim, NUM_REGIONS)

    def forward(self, obs_history):
        output, hn = self.rnn(obs_history)
        pred = self.out(output[:,-1,:])
        return pred

class TransformerTemporalModel(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(TransformerTemporalModel, self).__init__()
        encoder_layer = nn.TransformerEncoderLayer(d_model=hidden_dim, nhead=4)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=2)
        self.input_proj = nn.Linear(input_dim, hidden_dim)
        self.output_proj = nn.Linear(hidden_dim, hidden_dim)
    def forward(self, seq):
        x = self.input_proj(seq)
        x = x.permute(1,0,2)
        out = self.transformer(x)
        out = out.permute(1,0,2)
        return self.output_proj(out)

class GNNInteractionModel(nn.Module):
    def __init__(self, node_feature_dim):
        super(GNNInteractionModel, self).__init__()
        self.conv1 = GCNConv(node_feature_dim, HIDDEN_DIM)
        self.conv2 = GCNConv(HIDDEN_DIM, HIDDEN_DIM)
    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return x

class PolicyNetwork(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(PolicyNetwork, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(state_dim, HIDDEN_DIM),
            nn.ReLU(),
            nn.Linear(HIDDEN_DIM, action_dim)
        )
    def forward(self, state):
        mean = self.fc(state)
        mean = torch.tanh(mean)*5.0
        mean = F.softplus(mean)
        mean = torch.clamp(mean, max=5.0)
        return mean

class ValueNetwork(nn.Module):
    def __init__(self, state_dim):
        super(ValueNetwork, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(state_dim, HIDDEN_DIM),
            nn.ReLU(),
            nn.Linear(HIDDEN_DIM, 1)
        )
    def forward(self, state):
        return self.fc(state)

class SocialistEconomyEnv:
    def __init__(self):
        self.reset()
    def reset(self):
        self.R = torch.tensor(500.0, device=device)
        self.M = torch.tensor(1000.0, device=device)   # Money supply
        self.Z = torch.tensor(0.0, device=device)
        self.k = torch.ones(NUM_REGIONS, device=device)*50.0
        self.theta = torch.abs(torch.randn(NUM_REGIONS, device=device)) + 0.1
        self.region_obs = torch.randn(NUM_REGIONS, 10, device=device)
        self.t = 0
        self.done = False

        # NEW: We keep population here for possible future use
        self.population = population.clone()

        return self._get_state()
    def step(self, c_alloc, x_alloc, l_alloc):
        assert c_alloc.shape[0] == NUM_REGIONS
        assert x_alloc.shape[0] == NUM_REGIONS
        assert l_alloc.shape[0] == NUM_REGIONS

        y = torch.zeros(NUM_REGIONS, device=device)
        for i in range(NUM_REGIONS):
            y[i] = production(self.k[i], l_alloc[i], self.theta[i], self.Z)

        self.R = resource_update(self.R, c_alloc, x_alloc)
        self.k = capital_update(self.k, x_alloc)

        Z_shock = torch.randn(1, device=device)*std_Z
        self.Z = self.Z + Z_shock

        U = torch.zeros(NUM_REGIONS, device=device)
        for i in range(NUM_REGIONS):
            U[i] = utility_function(c_alloc[i], self.theta[i])

        # Compute inflation based on money supply changes
        # We'll implement a simple dynamic policy at the end of step:
        old_M = self.M.clone()
        Y = y.sum()
        # Price level P = M/Y
        P = self.M / Y
        # Let's define inflation as (M_{new} - M_old)/M_old after update
        # For now pi before update = 0, we adjust M:
        # DeltaM = phi_pi*(pi - pi_star) + phi_y*(Y - Y_star)
        # pi currently unknown, assume pi=0 for rule or stable scenario:
        # We'll just base policy on Y vs Y_star since pi not computed yet:
        pi_current = 0.0
        DeltaM = phi_pi*(pi_current - pi_star) + phi_y*(Y.item() - Y_star)
        self.M = self.M + DeltaM
        pi_new = (self.M - old_M)/old_M  # realized inflation

        self.t += 1
        if self.t >= TIME_STEPS:
            self.done = True

        with torch.no_grad():
            self.region_obs = self.region_obs + 0.01*torch.randn_like(self.region_obs)

        return U, self.done
    def _get_state(self):
        return (self.R, self.M, self.Z, self.k.mean(), self.theta.mean(), self.region_obs)

def compute_returns(rewards, gamma=GAMMA):
    returns = []
    R_ = 0
    for r in reversed(rewards):
        R_ = r + gamma*R_
        returns.insert(0,R_)
    return torch.tensor(returns, device=device, dtype=torch.float)

def main():
    vae = VAETypeInference(input_dim=10, latent_dim=LATENT_DIM).to(device)
    transformer = TransformerTemporalModel(input_dim=HIDDEN_DIM, hidden_dim=HIDDEN_DIM).to(device)
    gnn = GNNInteractionModel(node_feature_dim=HIDDEN_DIM).to(device)
    policy_net = PolicyNetwork(state_dim=HIDDEN_DIM + NUM_REGIONS*3, action_dim=NUM_REGIONS*3).to(device)
    value_net = ValueNetwork(state_dim=HIDDEN_DIM + NUM_REGIONS*3).to(device)
    demand_forecast = DemandForecastModel().to(device)

    optimizer = optim.Adam(list(vae.parameters())+
                           list(transformer.parameters())+
                           list(gnn.parameters())+
                           list(policy_net.parameters())+
                           list(value_net.parameters())+
                           list(demand_forecast.parameters()), lr=LEARNING_RATE)

    metrics_list = []

    # NEW: Data logging structures
    inputs_log = []
    params_log = []
    outputs_log = []

    for epoch in range(EPOCHS):
        for episode in range(EPISODES_PER_EPOCH):
            env = SocialistEconomyEnv()
            log_probs = []
            rewards = []
            allocations_history = []
            utilities_over_time = []

            done = False
            while not done:
                R, M, Z, mean_k, mean_theta, region_obs = env._get_state()
                recon, mu, logvar, z = vae(region_obs)
                vae_loss = vae.loss_function(recon, region_obs, mu, logvar)

                extra_feats = torch.randn(NUM_REGIONS, HIDDEN_DIM - LATENT_DIM, device=device)
                node_feats = torch.cat([z, extra_feats], dim=1)
                gnn_out = gnn(node_feats, edge_index)

                obs_for_forecast = region_obs.mean(dim=0, keepdim=True).unsqueeze(0)
                pred_demand = demand_forecast(obs_for_forecast).squeeze(0)

                global_vec = torch.cat([
                    gnn_out.mean(dim=0),
                    pred_demand,
                    torch.tensor([mean_k.item(), mean_theta.item(), R.item(), M.item(), Z.item()], device=device)
                ])

                needed_dim = HIDDEN_DIM + NUM_REGIONS*3
                if global_vec.shape[0] < needed_dim:
                    pad_size = needed_dim - global_vec.shape[0]
                    global_vec = torch.cat([global_vec, torch.zeros(pad_size, device=device)])
                global_state = global_vec.unsqueeze(0)

                mean_alloc = policy_net(global_state)
                c_alloc_mean = mean_alloc[0,:NUM_REGIONS]
                x_alloc_mean = mean_alloc[0,NUM_REGIONS:2*NUM_REGIONS]
                l_alloc_mean = mean_alloc[0,2*NUM_REGIONS:3*NUM_REGIONS]

                policy_dist_c = Normal(c_alloc_mean, 0.01*torch.ones_like(c_alloc_mean))
                policy_dist_x = Normal(x_alloc_mean, 0.01*torch.ones_like(x_alloc_mean))
                policy_dist_l = Normal(l_alloc_mean, 0.01*torch.ones_like(l_alloc_mean))

                max_alloc = env.R.item() / NUM_REGIONS / 10.0
                c_alloc = torch.clamp(policy_dist_c.sample(), min=0, max=max_alloc)
                x_alloc = torch.clamp(policy_dist_x.sample(), min=0, max=max_alloc)
                l_alloc = torch.clamp(policy_dist_l.sample(), min=1e-3, max=10.0)

                U, done = env.step(c_alloc, x_alloc, l_alloc)
                avg_U = U.mean().item()
                rewards.append(avg_U)

                log_p = (policy_dist_c.log_prob(c_alloc).sum() +
                         policy_dist_x.log_prob(x_alloc).sum() +
                         policy_dist_l.log_prob(l_alloc).sum())
                log_probs.append(log_p)

                allocations_history.append(c_alloc.detach())
                utilities_over_time.append(U.detach())

                # NEW: Logging inputs (state), parameters (allocations), and outputs (utility)
                inputs_log.append({
                    'Epoch': epoch+1,
                    'Episode': episode+1,
                    'Step': env.t,
                    'R': env.R.item(),
                    'M': env.M.item(),
                    'Z': env.Z.item(),
                    'mean_k': env.k.mean().item(),
                    'mean_theta': env.theta.mean().item()
                })

                params_log.append({
                    'Epoch': epoch+1,
                    'Episode': episode+1,
                    'Step': env.t,
                    'c_alloc_mean': c_alloc_mean.mean().item(),
                    'x_alloc_mean': x_alloc_mean.mean().item(),
                    'l_alloc_mean': l_alloc_mean.mean().item(),
                })

                outputs_log.append({
                    'Epoch': epoch+1,
                    'Episode': episode+1,
                    'Step': env.t,
                    'Utility': avg_U,
                    'c_alloc': c_alloc.mean().item(),
                    'x_alloc': x_alloc.mean().item(),
                    'l_alloc': l_alloc.mean().item()
                })

            returns = compute_returns(rewards, gamma=GAMMA)
            returns = (returns-returns.mean())/(returns.std()+1e-9)

            policy_loss = 0.0
            for lp, R_ in zip(log_probs, returns):
                policy_loss -= lp * R_

            utilities_tensor = torch.stack(utilities_over_time, dim=0)
            avg_utilities = utilities_tensor.mean(dim=0)
            mean_util = avg_utilities.mean().item()
            mean_alloc_val = torch.stack(allocations_history).mean(dim=0).mean().item()

            IC_loss = incentive_compatibility_loss(env.theta, allocations_history[-1])
            IR_loss = individual_rationality_loss(avg_utilities.mean())
            ostrom_loss_val = ostrom_cooperation_loss(allocations_history)
            resource_loss = resource_constraint_loss(env.R, allocations_history[-1], torch.zeros(NUM_REGIONS, device=device))

            total_loss = (vae_loss * WEIGHT_VAE +
                          IC_loss * WEIGHT_IC +
                          IR_loss * WEIGHT_IR +
                          ostrom_loss_val * WEIGHT_OSTROM +
                          resource_loss * WEIGHT_RESOURCE +
                          policy_loss * WEIGHT_POLICY)

            optimizer.zero_grad()
            total_loss.backward()
            torch.nn.utils.clip_grad_norm_(vae.parameters(), max_norm=1.0)
            torch.nn.utils.clip_grad_norm_(transformer.parameters(), max_norm=1.0)
            torch.nn.utils.clip_grad_norm_(gnn.parameters(), max_norm=1.0)
            torch.nn.utils.clip_grad_norm_(policy_net.parameters(), max_norm=1.0)
            torch.nn.utils.clip_grad_norm_(value_net.parameters(), max_norm=1.0)
            torch.nn.utils.clip_grad_norm_(demand_forecast.parameters(), max_norm=1.0)
            optimizer.step()

            # Print out inputs, parameters, outputs for debugging
            print(f"[Epoch {epoch+1}, Episode {episode+1}]")
            print("Inputs:")
            print(f" R={env.R.item():.4f}, M={env.M.item():.4f}, Z={env.Z.item():.4f}, mean_k={env.k.mean().item():.4f}, mean_theta={env.theta.mean().item():.4f}")
            print(f" region_obs mean={env.region_obs.mean().item():.4f}, std={env.region_obs.std().item():.4f}")

            print("Parameters (allocations):")
            print(f" c_alloc_mean={c_alloc_mean.mean().item():.4f}, x_alloc_mean={x_alloc_mean.mean().item():.4f}, l_alloc_mean={l_alloc_mean.mean().item():.4f}")
            print(f" c_alloc={c_alloc.mean().item():.4f}, x_alloc={x_alloc.mean().item():.4f}, l_alloc={l_alloc.mean().item():.4f}")

            print("Outputs:")
            print(f" Utility={mean_util:.4f}")
            print(f" Total Loss={total_loss.item():.4f}, VAE Loss={vae_loss.item():.4f}, IC Loss={IC_loss.item():.4f}, IR Loss={IR_loss.item():.4f}, Ostrom Loss={ostrom_loss_val.item():.4f}, Resource Loss={resource_loss.item():.4f}, Policy Loss={policy_loss.item():.4f}")
            print("-"*50)

            metrics_list.append({
                'Epoch': epoch+1,
                'Episode': episode+1,
                'R': env.R.item(),
                'M': env.M.item(),
                'Z': env.Z.item(),
                'Mean_k': env.k.mean().item(),
                'Mean_theta': env.theta.mean().item(),
                'region_obs_mean': env.region_obs.mean().item(),
                'region_obs_std': env.region_obs.std().item(),
                'c_alloc_mean': c_alloc_mean.mean().item(),
                'x_alloc_mean': x_alloc_mean.mean().item(),
                'l_alloc_mean': l_alloc_mean.mean().item(),
                'c_alloc': c_alloc.mean().item(),
                'x_alloc': x_alloc.mean().item(),
                'l_alloc': l_alloc.mean().item(),
                'Utility': mean_util,
                'Total Loss': total_loss.item(),
                'VAE Loss': vae_loss.item(),
                'IC Loss': IC_loss.item(),
                'IR Loss': IR_loss.item(),
                'Ostrom Loss': ostrom_loss_val.item(),
                'Resource Loss': resource_loss.item(),
                'Policy Loss': policy_loss.item()
            })

    # Save metrics to CSV
    metrics_df = pd.DataFrame(metrics_list)
    metrics_df.to_csv('training_metrics.csv', index=False)
    print("Metrics saved to training_metrics.csv")

    # NEW: Convert logs to DataFrames and save
    inputs_df = pd.DataFrame(inputs_log)
    params_df = pd.DataFrame(params_log)
    outputs_df = pd.DataFrame(outputs_log)

    inputs_df.to_csv('enhanced_inputs.csv', index=False)
    params_df.to_csv('enhanced_params.csv', index=False)
    outputs_df.to_csv('enhanced_outputs.csv', index=False)
    print("Enhanced logging data saved to CSV.")

# %%
if __name__ == "__main__":
    main()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Outputs:
#  Utility=1.1186
#  Total Loss=4.4124, VAE Loss=0.8326, IC Loss=0.0840, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=3.4956
# --------------------------------------------------
# [Epoch 274, Episode 1]
# Inputs:
#  R=471.6613, M=524.5308, Z=-0.0274, mean_k=50.8102, mean_theta=0.9150
#  region_obs mean=0.0181, std=0.9980
# Parameters (allocations):
#  c_alloc_mean=2.9900, x_alloc_mean=2.8918, l_alloc_mean=2.0041
#  c_alloc=2.9888, x_alloc=2.8908, l_alloc=2.0064
# Outputs:
#  Utility=1.2569
#  Total Loss=-3.8096, VAE Loss=1.0388, IC Loss=0.1124, IR Loss=0.0000, Ostrom Loss=0.0001, Resource Loss=0.0000, Policy Loss=-4.9610
# --------------------------------------------------
# [Epoch 274, Episode 2]
# Inputs:
#  R=471.8211, M=523.5358, Z=-0.0476, mean_k=50.7528, mean_theta=1.5255
#  region_obs mean=0.2024, std=0.9285
# Parameters (allocations):
#  c_alloc_mean=2.9903, x_alloc_mean=2.8680, l_alloc_mean=2.0041
#  c_alloc=2.9860, x_alloc=2.8659, l_alloc=2.0067
# Outputs:
#  Utility=1.2320
#  Total Loss=-7.6167, VAE Loss=1.0140, IC Loss=2.1594, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-10.7902
# --------------------------------------------------
# [Epoch 275, Episode 1]
# Inputs:
#  R=470.5445, M=518.1700, Z=0.0007, mean_k=50.9459, mean_theta=0.9876
#  region_obs mean=0.1256, std=1.0395
# Parameters (allocations):
#  c_alloc_mean=2.9853, x_alloc_mean=2.9051, l_alloc_mean=2.0041
#  c_alloc=2.9835, x_alloc=2.9047, l_alloc=2.0088
# Outputs:
#  Utility=1.2757
#  Total Loss=6.3050, VAE Loss=1.1666, IC Loss=0.2979, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=4.8402
# --------------------------------------------------
# [Epoch 275, Episode 2]
# Inputs:
#  R=472.9122, M=521.5562, Z=-0.0217, mean_k=50.6164, mean_theta=1.3100
#  region_obs mean=-0.1144, std=1.0081
# Parameters (allocations):
#  c_alloc_mean=2.9844, x_alloc_mean=2.8893, l_alloc_mean=2.0041
#  c_alloc=2.9836, x_alloc=2.8973, l_alloc=2.0003
# Outputs:
#  Utility=1.3534
#  Total Loss=0.6942, VAE Loss=1.1717, IC Loss=0.8969, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-1.3746
# --------------------------------------------------
# [Epoch 276, Episode 1]
# Inputs:
#  R=470.9650, M=516.4167, Z=0.0069, mean_k=50.9078, mean_theta=0.7293
#  region_obs mean=-0.0610, std=0.8025
# Parameters (allocations):
#  c_alloc_mean=2.9810, x_alloc_mean=2.8965, l_alloc_mean=2.0041
#  c_alloc=2.9692, x_alloc=2.8947, l_alloc=2.0011
# Outputs:
#  Utility=1.2769
#  Total Loss=-12.4199, VAE Loss=0.7084, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=-13.1287
# --------------------------------------------------
# [Epoch 276, Episode 2]
# Inputs:
#  R=471.8866, M=521.7685, Z=0.0011, mean_k=50.7647, mean_theta=0.7549
#  region_obs mean=-0.1276, std=1.1936
# Parameters (allocations):
#  c_alloc_mean=2.9865, x_alloc_mean=2.8927, l_alloc_mean=2.0041
#  c_alloc=2.9845, x_alloc=2.8895, l_alloc=2.0098
# Outputs:
#  Utility=1.0054
#  Total Loss=6.0530, VAE Loss=1.7385, IC Loss=0.7876, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=3.5267
# --------------------------------------------------
# [Epoch 277, Episode 1]
# Inputs:
#  R=471.0329, M=515.9183, Z=0.0032, mean_k=50.8802, mean_theta=0.8063
#  region_obs mean=-0.0932, std=0.9587
# Parameters (allocations):
#  c_alloc_mean=2.9805, x_alloc_mean=2.8891, l_alloc_mean=2.0041
#  c_alloc=2.9781, x_alloc=2.8925, l_alloc=2.0093
# Outputs:
#  Utility=1.2614
#  Total Loss=4.4716, VAE Loss=0.9441, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=3.5272
# --------------------------------------------------
# [Epoch 277, Episode 2]
# Inputs:
#  R=470.5728, M=516.6157, Z=0.0331, mean_k=50.9485, mean_theta=0.7797
#  region_obs mean=-0.0267, std=1.2090
# Parameters (allocations):
#  c_alloc_mean=2.9749, x_alloc_mean=2.9002, l_alloc_mean=2.0041
#  c_alloc=2.9762, x_alloc=2.8981, l_alloc=2.0083
# Outputs:
#  Utility=0.9082
#  Total Loss=5.0383, VAE Loss=1.5858, IC Loss=1.3472, IR Loss=0.0000, Ostrom Loss=0.0005, Resource Loss=0.0000, Policy Loss=2.1048
# --------------------------------------------------
# [Epoch 278, Episode 1]
# Inputs:
#  R=471.1911, M=517.6237, Z=-0.0473, mean_k=50.8772, mean_theta=0.6586
#  region_obs mean=0.1356, std=0.9524
# Parameters (allocations):
#  c_alloc_mean=2.9805, x_alloc_mean=2.9194, l_alloc_mean=2.0041
#  c_alloc=2.9877, x_alloc=2.9264, l_alloc=2.0066
# Outputs:
#  Utility=1.1645
#  Total Loss=-1.2195, VAE Loss=1.1336, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-2.3534
# --------------------------------------------------
# [Epoch 278, Episode 2]
# Inputs:
#  R=472.0387, M=528.6695, Z=0.0107, mean_k=50.7169, mean_theta=1.4099
#  region_obs mean=-0.0619, std=1.0533
# Parameters (allocations):
#  c_alloc_mean=2.9890, x_alloc_mean=2.8934, l_alloc_mean=2.0041
#  c_alloc=2.9926, x_alloc=2.8875, l_alloc=2.0033
# Outputs:
#  Utility=1.4837
#  Total Loss=-2.7138, VAE Loss=1.2518, IC Loss=0.5190, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-4.4848
# --------------------------------------------------
# [Epoch 279, Episode 1]
# Inputs:
#  R=470.7069, M=514.4283, Z=-0.0433, mean_k=50.9293, mean_theta=0.6482
#  region_obs mean=-0.1494, std=1.0921
# Parameters (allocations):
#  c_alloc_mean=2.9847, x_alloc_mean=2.9061, l_alloc_mean=2.0041
#  c_alloc=2.9832, x_alloc=2.9044, l_alloc=1.9959
# Outputs:
#  Utility=1.1997
#  Total Loss=-1.6671, VAE Loss=1.4105, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-3.0777
# --------------------------------------------------
# [Epoch 279, Episode 2]
# Inputs:
#  R=470.2397, M=521.8894, Z=-0.0419, mean_k=51.0095, mean_theta=0.7288
#  region_obs mean=0.0224, std=0.8591
# Parameters (allocations):
#  c_alloc_mean=2.9865, x_alloc_mean=2.8858, l_alloc_mean=2.0041
#  c_alloc=2.9907, x_alloc=2.8933, l_alloc=2.0017
# Outputs:
#  Utility=1.1198
#  Total Loss=0.5544, VAE Loss=0.8861, IC Loss=0.0771, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-0.4090
# --------------------------------------------------
# [Epoch 280, Episode 1]
# Inputs:
#  R=472.1226, M=518.7359, Z=0.0604, mean_k=50.7124, mean_theta=0.5917
#  region_obs mean=0.1263, std=1.0002
# Parameters (allocations):
#  c_alloc_mean=2.9861, x_alloc_mean=2.8835, l_alloc_mean=2.0041
#  c_alloc=2.9834, x_alloc=2.8879, l_alloc=2.0072
# Outputs:
#  Utility=0.9727
#  Total Loss=0.2503, VAE Loss=1.1393, IC Loss=0.2488, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-1.1381
# --------------------------------------------------
# [Epoch 280, Episode 2]
# Inputs:
#  R=472.1576, M=525.6867, Z=0.0041, mean_k=50.7185, mean_theta=0.8593
#  region_obs mean=0.0689, std=0.8077
# Parameters (allocations):
#  c_alloc_mean=2.9900, x_alloc_mean=2.9020, l_alloc_mean=2.0041
#  c_alloc=2.9826, x_alloc=2.9017, l_alloc=2.0032
# Outputs:
#  Utility=1.1265
#  Total Loss=-1.0402, VAE Loss=0.8594, IC Loss=0.4995, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-2.3993
# --------------------------------------------------
# [Epoch 281, Episode 1]
# Inputs:
#  R=470.4452, M=516.1100, Z=-0.0239, mean_k=50.9820, mean_theta=0.4756
#  region_obs mean=0.0306, std=0.9248
# Parameters (allocations):
#  c_alloc_mean=2.9832, x_alloc_mean=2.9072, l_alloc_mean=2.0041
#  c_alloc=2.9803, x_alloc=2.9123, l_alloc=2.0105
# Outputs:
#  Utility=0.9110
#  Total Loss=-2.0122, VAE Loss=0.9401, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-2.9526
# --------------------------------------------------
# [Epoch 281, Episode 2]
# Inputs:
#  R=470.6809, M=522.0703, Z=0.0269, mean_k=50.9294, mean_theta=0.8182
#  region_obs mean=0.0844, std=0.9846
# Parameters (allocations):
#  c_alloc_mean=2.9888, x_alloc_mean=2.8805, l_alloc_mean=2.0041
#  c_alloc=2.9930, x_alloc=2.8740, l_alloc=1.9996
# Outputs:
#  Utility=1.1309
#  Total Loss=1.3798, VAE Loss=1.0668, IC Loss=0.4169, IR Loss=0.0000, Ostrom Loss=0.0001, Resource Loss=0.0000, Policy Loss=-0.1040
# --------------------------------------------------
# [Epoch 282, Episode 1]
# Inputs:
#  R=471.0479, M=517.1992, Z=-0.0370, mean_k=50.8686, mean_theta=0.3506
#  region_obs mean=0.1384, std=0.8616
# Parameters (allocations):
#  c_alloc_mean=2.9814, x_alloc_mean=2.9038, l_alloc_mean=2.0041
#  c_alloc=2.9871, x_alloc=2.9039, l_alloc=2.0067
# Outputs:
#  Utility=0.6172
#  Total Loss=5.6475, VAE Loss=0.8322, IC Loss=0.8212, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=3.9937
# --------------------------------------------------
# [Epoch 282, Episode 2]
# Inputs:
#  R=470.1863, M=518.4756, Z=-0.1123, mean_k=50.9841, mean_theta=0.4659
#  region_obs mean=0.1516, std=1.0480
# Parameters (allocations):
#  c_alloc_mean=2.9867, x_alloc_mean=2.8659, l_alloc_mean=2.0041
#  c_alloc=2.9859, x_alloc=2.8575, l_alloc=2.0075
# Outputs:
#  Utility=0.6799
#  Total Loss=10.2371, VAE Loss=1.2052, IC Loss=1.1252, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=7.9064
# --------------------------------------------------
# [Epoch 283, Episode 1]
# Inputs:
#  R=471.4037, M=517.2227, Z=-0.0506, mean_k=50.8359, mean_theta=0.4874
#  region_obs mean=0.0019, std=1.0222
# Parameters (allocations):
#  c_alloc_mean=2.9816, x_alloc_mean=2.8923, l_alloc_mean=2.0041
#  c_alloc=2.9845, x_alloc=2.8980, l_alloc=2.0029
# Outputs:
#  Utility=0.8420
#  Total Loss=-0.8803, VAE Loss=1.1178, IC Loss=0.4284, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-2.4268
# --------------------------------------------------
# [Epoch 283, Episode 2]
# Inputs:
#  R=471.8074, M=517.7960, Z=0.0190, mean_k=50.7577, mean_theta=0.9919
#  region_obs mean=0.0876, std=1.0153
# Parameters (allocations):
#  c_alloc_mean=2.9829, x_alloc_mean=2.8762, l_alloc_mean=2.0041
#  c_alloc=2.9820, x_alloc=2.8781, l_alloc=2.0051
# Outputs:
#  Utility=1.3674
#  Total Loss=-9.9319, VAE Loss=1.0389, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-10.9711
# --------------------------------------------------
# [Epoch 284, Episode 1]
# Inputs:
#  R=470.9004, M=516.8483, Z=0.0772, mean_k=50.9308, mean_theta=0.2780
#  region_obs mean=-0.1487, std=1.0353
# Parameters (allocations):
#  c_alloc_mean=2.9870, x_alloc_mean=2.9012, l_alloc_mean=2.0041
#  c_alloc=2.9871, x_alloc=2.9043, l_alloc=1.9972
# Outputs:
#  Utility=0.6743
#  Total Loss=17.3467, VAE Loss=1.1470, IC Loss=0.0872, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=16.1123
# --------------------------------------------------
# [Epoch 284, Episode 2]
# Inputs:
#  R=471.5680, M=513.7858, Z=-0.0159, mean_k=50.8002, mean_theta=0.7340
#  region_obs mean=0.0278, std=0.9402
# Parameters (allocations):
#  c_alloc_mean=2.9853, x_alloc_mean=2.8818, l_alloc_mean=2.0041
#  c_alloc=2.9804, x_alloc=2.8778, l_alloc=1.9993
# Outputs:
#  Utility=0.9724
#  Total Loss=-4.3633, VAE Loss=1.0468, IC Loss=0.8988, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-6.3093
# --------------------------------------------------
# [Epoch 285, Episode 1]
# Inputs:
#  R=470.9696, M=527.3375, Z=0.0267, mean_k=50.8903, mean_theta=1.0123
#  region_obs mean=0.0770, std=0.9475
# Parameters (allocations):
#  c_alloc_mean=2.9900, x_alloc_mean=2.8715, l_alloc_mean=2.0041
#  c_alloc=2.9911, x_alloc=2.8750, l_alloc=2.0034
# Outputs:
#  Utility=1.2279
#  Total Loss=0.7916, VAE Loss=0.9708, IC Loss=0.6324, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-0.8118
# --------------------------------------------------
# [Epoch 285, Episode 2]
# Inputs:
#  R=472.3676, M=521.8862, Z=-0.0452, mean_k=50.6651, mean_theta=1.2431
#  region_obs mean=-0.1869, std=0.8509
# Parameters (allocations):
#  c_alloc_mean=2.9836, x_alloc_mean=2.8717, l_alloc_mean=2.0041
#  c_alloc=2.9776, x_alloc=2.8702, l_alloc=1.9993
# Outputs:
#  Utility=1.5292
#  Total Loss=3.5016, VAE Loss=0.8989, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=2.6024
# --------------------------------------------------
# [Epoch 286, Episode 1]
# Inputs:
#  R=471.8350, M=516.3687, Z=0.0060, mean_k=50.7506, mean_theta=0.5844
#  region_obs mean=-0.1264, std=1.0594
# Parameters (allocations):
#  c_alloc_mean=2.9810, x_alloc_mean=2.8839, l_alloc_mean=2.0041
#  c_alloc=2.9762, x_alloc=2.8902, l_alloc=2.0065
# Outputs:
#  Utility=0.6804
#  Total Loss=6.1062, VAE Loss=1.1851, IC Loss=1.6766, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=3.2441
# --------------------------------------------------
# [Epoch 286, Episode 2]
# Inputs:
#  R=470.8543, M=524.2798, Z=0.0734, mean_k=50.8920, mean_theta=0.8152
#  region_obs mean=-0.0851, std=1.0518
# Parameters (allocations):
#  c_alloc_mean=2.9887, x_alloc_mean=2.8983, l_alloc_mean=2.0041
#  c_alloc=2.9943, x_alloc=2.8981, l_alloc=2.0079
# Outputs:
#  Utility=1.0428
#  Total Loss=23.4231, VAE Loss=1.1900, IC Loss=0.8368, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=21.3961
# --------------------------------------------------
# [Epoch 287, Episode 1]
# Inputs:
#  R=473.0753, M=525.6022, Z=-0.0393, mean_k=50.5452, mean_theta=1.1962
#  region_obs mean=0.0326, std=1.0445
# Parameters (allocations):
#  c_alloc_mean=2.9813, x_alloc_mean=2.8586, l_alloc_mean=2.0041
#  c_alloc=2.9768, x_alloc=2.8559, l_alloc=2.0021
# Outputs:
#  Utility=1.1386
#  Total Loss=2.4898, VAE Loss=1.1766, IC Loss=1.6553, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-0.3424
# --------------------------------------------------
# [Epoch 287, Episode 2]
# Inputs:
#  R=470.7896, M=518.7836, Z=0.0199, mean_k=50.8976, mean_theta=0.8425
#  region_obs mean=0.0435, std=1.1637
# Parameters (allocations):
#  c_alloc_mean=2.9859, x_alloc_mean=2.8760, l_alloc_mean=2.0041
#  c_alloc=2.9888, x_alloc=2.8783, l_alloc=2.0011
# Outputs:
#  Utility=1.1194
#  Total Loss=-1.7638, VAE Loss=1.5668, IC Loss=0.5761, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-3.9069
# --------------------------------------------------
# [Epoch 288, Episode 1]
# Inputs:
#  R=470.6372, M=515.6823, Z=0.0344, mean_k=50.9553, mean_theta=0.4160
#  region_obs mean=0.0799, std=0.8534
# Parameters (allocations):
#  c_alloc_mean=2.9795, x_alloc_mean=2.8929, l_alloc_mean=2.0041
#  c_alloc=2.9788, x_alloc=2.8873, l_alloc=2.0151
# Outputs:
#  Utility=0.9682
#  Total Loss=2.3004, VAE Loss=0.8878, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=1.4122
# --------------------------------------------------
# [Epoch 288, Episode 2]
# Inputs:
#  R=472.4430, M=526.3671, Z=-0.0278, mean_k=50.6843, mean_theta=1.1611
#  region_obs mean=-0.1944, std=0.9994
# Parameters (allocations):
#  c_alloc_mean=2.9878, x_alloc_mean=2.8753, l_alloc_mean=2.0041
#  c_alloc=2.9801, x_alloc=2.8752, l_alloc=2.0029
# Outputs:
#  Utility=1.2169
#  Total Loss=9.3699, VAE Loss=1.1640, IC Loss=1.1653, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=7.0404
# --------------------------------------------------
# [Epoch 289, Episode 1]
# Inputs:
#  R=472.9364, M=522.5718, Z=-0.0223, mean_k=50.6117, mean_theta=1.0812
#  region_obs mean=-0.0113, std=1.1412
# Parameters (allocations):
#  c_alloc_mean=2.9803, x_alloc_mean=2.8731, l_alloc_mean=2.0041
#  c_alloc=2.9771, x_alloc=2.8734, l_alloc=2.0029
# Outputs:
#  Utility=1.4384
#  Total Loss=1.7128, VAE Loss=1.3839, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=0.3285
# --------------------------------------------------
# [Epoch 289, Episode 2]
# Inputs:
#  R=470.9309, M=520.6783, Z=-0.0541, mean_k=50.9039, mean_theta=0.7317
#  region_obs mean=-0.1194, std=0.9775
# Parameters (allocations):
#  c_alloc_mean=2.9788, x_alloc_mean=2.8767, l_alloc_mean=2.0041
#  c_alloc=2.9813, x_alloc=2.8740, l_alloc=2.0061
# Outputs:
#  Utility=1.1633
#  Total Loss=2.5270, VAE Loss=0.9918, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=1.5348
# --------------------------------------------------
# [Epoch 290, Episode 1]
# Inputs:
#  R=472.6018, M=524.5080, Z=0.0158, mean_k=50.6399, mean_theta=1.3889
#  region_obs mean=0.1495, std=1.0845
# Parameters (allocations):
#  c_alloc_mean=2.9818, x_alloc_mean=2.8716, l_alloc_mean=2.0041
#  c_alloc=2.9837, x_alloc=2.8700, l_alloc=1.9951
# Outputs:
#  Utility=1.7116
#  Total Loss=-2.7937, VAE Loss=1.1964, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-3.9904
# --------------------------------------------------
# [Epoch 290, Episode 2]
# Inputs:
#  R=471.2350, M=522.5059, Z=0.0148, mean_k=50.8626, mean_theta=0.8609
#  region_obs mean=-0.1535, std=1.1574
# Parameters (allocations):
#  c_alloc_mean=2.9889, x_alloc_mean=2.9043, l_alloc_mean=2.0041
#  c_alloc=2.9882, x_alloc=2.9045, l_alloc=2.0043
# Outputs:
#  Utility=1.1038
#  Total Loss=-3.6216, VAE Loss=1.5817, IC Loss=0.6720, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-5.8755
# --------------------------------------------------
# [Epoch 291, Episode 1]
# Inputs:
#  R=471.1463, M=517.8560, Z=0.0291, mean_k=50.8598, mean_theta=0.5482
#  region_obs mean=-0.0602, std=0.8207
# Parameters (allocations):
#  c_alloc_mean=2.9793, x_alloc_mean=2.8977, l_alloc_mean=2.0041
#  c_alloc=2.9830, x_alloc=2.9069, l_alloc=2.0069
# Outputs:
#  Utility=0.9992
#  Total Loss=3.4432, VAE Loss=0.7553, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=2.6875
# --------------------------------------------------
# [Epoch 291, Episode 2]
# Inputs:
#  R=470.2333, M=523.0912, Z=0.0094, mean_k=50.9878, mean_theta=0.9191
#  region_obs mean=-0.0416, std=0.8204
# Parameters (allocations):
#  c_alloc_mean=2.9895, x_alloc_mean=2.8802, l_alloc_mean=2.0041
#  c_alloc=3.0000, x_alloc=2.8851, l_alloc=2.0024
# Outputs:
#  Utility=1.4245
#  Total Loss=3.3870, VAE Loss=0.8244, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0001, Resource Loss=0.0000, Policy Loss=2.5625
# --------------------------------------------------
# [Epoch 292, Episode 1]
# Inputs:
#  R=471.2314, M=520.8867, Z=-0.0091, mean_k=50.8337, mean_theta=0.8787
#  region_obs mean=-0.1434, std=0.8823
# Parameters (allocations):
#  c_alloc_mean=2.9874, x_alloc_mean=2.8550, l_alloc_mean=2.0041
#  c_alloc=2.9779, x_alloc=2.8556, l_alloc=2.0067
# Outputs:
#  Utility=1.0200
#  Total Loss=3.0243, VAE Loss=0.8554, IC Loss=1.1998, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=0.9689
# --------------------------------------------------
# [Epoch 292, Episode 2]
# Inputs:
#  R=472.2992, M=524.0269, Z=-0.0085, mean_k=50.6826, mean_theta=1.0780
#  region_obs mean=0.0645, std=0.9119
# Parameters (allocations):
#  c_alloc_mean=2.9896, x_alloc_mean=2.8918, l_alloc_mean=2.0041
#  c_alloc=2.9921, x_alloc=2.8983, l_alloc=2.0041
# Outputs:
#  Utility=1.1965
#  Total Loss=6.0594, VAE Loss=0.9783, IC Loss=0.9294, IR Loss=0.0000, Ostrom Loss=0.0001, Resource Loss=0.0000, Policy Loss=4.1516
# --------------------------------------------------
# [Epoch 293, Episode 1]
# Inputs:
#  R=469.5193, M=516.9526, Z=0.0346, mean_k=51.1057, mean_theta=0.4338
#  region_obs mean=0.1375, std=1.0101
# Parameters (allocations):
#  c_alloc_mean=2.9865, x_alloc_mean=2.8758, l_alloc_mean=2.0041
#  c_alloc=2.9886, x_alloc=2.8818, l_alloc=2.0049
# Outputs:
#  Utility=0.9801
#  Total Loss=-5.7108, VAE Loss=1.1388, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-6.8498
# --------------------------------------------------
# [Epoch 293, Episode 2]
# Inputs:
#  R=470.9837, M=520.8666, Z=-0.0381, mean_k=50.8832, mean_theta=0.9546
#  region_obs mean=-0.0115, std=1.0333
# Parameters (allocations):
#  c_alloc_mean=2.9863, x_alloc_mean=2.8848, l_alloc_mean=2.0041
#  c_alloc=2.9927, x_alloc=2.8841, l_alloc=2.0121
# Outputs:
#  Utility=0.8294
#  Total Loss=4.7378, VAE Loss=1.2097, IC Loss=2.4139, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=1.1139
# --------------------------------------------------
# [Epoch 294, Episode 1]
# Inputs:
#  R=471.0488, M=522.5507, Z=0.0530, mean_k=50.8780, mean_theta=0.8552
#  region_obs mean=-0.1889, std=1.0760
# Parameters (allocations):
#  c_alloc_mean=2.9866, x_alloc_mean=2.8921, l_alloc_mean=2.0041
#  c_alloc=2.9847, x_alloc=2.8882, l_alloc=2.0057
# Outputs:
#  Utility=1.0743
#  Total Loss=4.6048, VAE Loss=1.3475, IC Loss=0.8103, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=2.4468
# --------------------------------------------------
# [Epoch 294, Episode 2]
# Inputs:
#  R=472.7154, M=525.9684, Z=-0.0097, mean_k=50.6367, mean_theta=1.1552
#  region_obs mean=0.1716, std=0.9673
# Parameters (allocations):
#  c_alloc_mean=2.9915, x_alloc_mean=2.8805, l_alloc_mean=2.0041
#  c_alloc=2.9864, x_alloc=2.8815, l_alloc=2.0063
# Outputs:
#  Utility=1.1336
#  Total Loss=9.6744, VAE Loss=1.0881, IC Loss=1.5462, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=7.0399
# --------------------------------------------------
# [Epoch 295, Episode 1]
# Inputs:
#  R=470.8021, M=516.2564, Z=-0.0359, mean_k=50.9521, mean_theta=0.6315
#  region_obs mean=0.0227, std=1.1994
# Parameters (allocations):
#  c_alloc_mean=2.9833, x_alloc_mean=2.8982, l_alloc_mean=2.0041
#  c_alloc=2.9834, x_alloc=2.8950, l_alloc=2.0038
# Outputs:
#  Utility=0.9825
#  Total Loss=11.1935, VAE Loss=1.5397, IC Loss=0.3406, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=9.3129
# --------------------------------------------------
# [Epoch 295, Episode 2]
# Inputs:
#  R=471.3536, M=514.9754, Z=-0.0011, mean_k=50.8382, mean_theta=0.3443
#  region_obs mean=-0.1514, std=1.0659
# Parameters (allocations):
#  c_alloc_mean=2.9817, x_alloc_mean=2.8890, l_alloc_mean=2.0041
#  c_alloc=2.9903, x_alloc=2.8931, l_alloc=2.0020
# Outputs:
#  Utility=0.9095
#  Total Loss=-19.6173, VAE Loss=1.3228, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-20.9404
# --------------------------------------------------
# [Epoch 296, Episode 1]
# Inputs:
#  R=472.1257, M=516.7282, Z=-0.0002, mean_k=50.7461, mean_theta=0.6765
#  region_obs mean=0.0504, std=1.0156
# Parameters (allocations):
#  c_alloc_mean=2.9826, x_alloc_mean=2.8977, l_alloc_mean=2.0041
#  c_alloc=2.9829, x_alloc=2.9032, l_alloc=2.0075
# Outputs:
#  Utility=1.0597
#  Total Loss=14.9099, VAE Loss=1.1121, IC Loss=0.2056, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=13.5920
# --------------------------------------------------
# [Epoch 296, Episode 2]
# Inputs:
#  R=470.4822, M=520.2556, Z=0.0079, mean_k=50.9318, mean_theta=0.6897
#  region_obs mean=-0.0374, std=1.0019
# Parameters (allocations):
#  c_alloc_mean=2.9886, x_alloc_mean=2.8896, l_alloc_mean=2.0041
#  c_alloc=2.9919, x_alloc=2.8890, l_alloc=2.0092
# Outputs:
#  Utility=1.0901
#  Total Loss=3.8521, VAE Loss=1.1605, IC Loss=0.1237, IR Loss=0.0000, Ostrom Loss=0.0001, Resource Loss=0.0000, Policy Loss=2.5678
# --------------------------------------------------
# [Epoch 297, Episode 1]
# Inputs:
#  R=471.4012, M=517.1651, Z=-0.0284, mean_k=50.8150, mean_theta=0.8316
#  region_obs mean=-0.0630, std=1.2058
# Parameters (allocations):
#  c_alloc_mean=2.9850, x_alloc_mean=2.8932, l_alloc_mean=2.0041
#  c_alloc=2.9848, x_alloc=2.8948, l_alloc=2.0081
# Outputs:
#  Utility=1.2050
#  Total Loss=2.0171, VAE Loss=1.5977, IC Loss=0.0821, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=0.3371
# --------------------------------------------------
# [Epoch 297, Episode 2]
# Inputs:
#  R=470.9704, M=520.8743, Z=0.0390, mean_k=50.8995, mean_theta=0.7130
#  region_obs mean=0.0289, std=0.9269
# Parameters (allocations):
#  c_alloc_mean=2.9875, x_alloc_mean=2.9033, l_alloc_mean=2.0041
#  c_alloc=2.9808, x_alloc=2.9003, l_alloc=1.9988
# Outputs:
#  Utility=0.9215
#  Total Loss=14.6789, VAE Loss=1.0068, IC Loss=1.0287, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=12.6432
# --------------------------------------------------
# [Epoch 298, Episode 1]
# Inputs:
#  R=472.6151, M=522.6351, Z=-0.0694, mean_k=50.6780, mean_theta=1.2632
#  region_obs mean=-0.0115, std=1.1161
# Parameters (allocations):
#  c_alloc_mean=2.9799, x_alloc_mean=2.8635, l_alloc_mean=2.0041
#  c_alloc=2.9774, x_alloc=2.8621, l_alloc=2.0036
# Outputs:
#  Utility=1.2198
#  Total Loss=4.7932, VAE Loss=1.4788, IC Loss=1.3934, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=1.9207
# --------------------------------------------------
# [Epoch 298, Episode 2]
# Inputs:
#  R=472.9026, M=527.5038, Z=0.0231, mean_k=50.5849, mean_theta=1.2722
#  region_obs mean=0.1735, std=1.0575
# Parameters (allocations):
#  c_alloc_mean=2.9886, x_alloc_mean=2.8840, l_alloc_mean=2.0041
#  c_alloc=2.9959, x_alloc=2.8778, l_alloc=2.0025
# Outputs:
#  Utility=1.5362
#  Total Loss=-3.1417, VAE Loss=1.1591, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0001, Resource Loss=0.0000, Policy Loss=-4.3010
# --------------------------------------------------
# [Epoch 299, Episode 1]
# Inputs:
#  R=470.9115, M=523.3314, Z=-0.0089, mean_k=50.8976, mean_theta=0.8486
#  region_obs mean=0.0019, std=1.0799
# Parameters (allocations):
#  c_alloc_mean=2.9893, x_alloc_mean=2.8771, l_alloc_mean=2.0041
#  c_alloc=2.9889, x_alloc=2.8732, l_alloc=2.0101
# Outputs:
#  Utility=1.0527
#  Total Loss=4.6456, VAE Loss=1.2474, IC Loss=0.8854, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=2.5127
# --------------------------------------------------
# [Epoch 299, Episode 2]
# Inputs:
#  R=471.6163, M=521.3200, Z=-0.0078, mean_k=50.7784, mean_theta=1.0534
#  region_obs mean=-0.0818, std=0.9253
# Parameters (allocations):
#  c_alloc_mean=2.9878, x_alloc_mean=2.8861, l_alloc_mean=2.0041
#  c_alloc=2.9886, x_alloc=2.8877, l_alloc=2.0080
# Outputs:
#  Utility=1.5816
#  Total Loss=-4.4442, VAE Loss=0.8867, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-5.3311
# --------------------------------------------------
# [Epoch 300, Episode 1]
# Inputs:
#  R=472.0661, M=521.1578, Z=-0.0277, mean_k=50.7327, mean_theta=0.8604
#  region_obs mean=-0.1349, std=1.1024
# Parameters (allocations):
#  c_alloc_mean=2.9766, x_alloc_mean=2.9030, l_alloc_mean=2.0041
#  c_alloc=2.9743, x_alloc=2.9042, l_alloc=2.0043
# Outputs:
#  Utility=1.3978
#  Total Loss=11.8476, VAE Loss=1.4563, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=10.3908
# --------------------------------------------------
# [Epoch 300, Episode 2]
# Inputs:
#  R=470.9687, M=514.4802, Z=0.0310, mean_k=50.9291, mean_theta=0.5166
#  region_obs mean=-0.0212, std=0.9501
# Parameters (allocations):
#  c_alloc_mean=2.9785, x_alloc_mean=2.8827, l_alloc_mean=2.0041
#  c_alloc=2.9841, x_alloc=2.8833, l_alloc=2.0063
# Outputs:
#  Utility=0.6201
#  Total Loss=6.6773, VAE Loss=1.0597, IC Loss=1.6731, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=3.9442
# --------------------------------------------------
# [Epoch 301, Episode 1]
# Inputs:
#  R=471.6049, M=524.8668, Z=0.0176, mean_k=50.7811, mean_theta=1.4847
#  region_obs mean=0.1536, std=1.0651
# Parameters (allocations):
#  c_alloc_mean=2.9896, x_alloc_mean=2.8380, l_alloc_mean=2.0041
#  c_alloc=2.9815, x_alloc=2.8414, l_alloc=2.0044
# Outputs:
#  Utility=1.5441
#  Total Loss=17.2972, VAE Loss=1.3272, IC Loss=0.5049, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=15.4648
# --------------------------------------------------
# [Epoch 301, Episode 2]
# Inputs:
#  R=472.8177, M=525.3216, Z=0.0449, mean_k=50.6110, mean_theta=1.2518
#  region_obs mean=0.0739, std=1.1107
# Parameters (allocations):
#  c_alloc_mean=2.9811, x_alloc_mean=2.9035, l_alloc_mean=2.0041
#  c_alloc=2.9817, x_alloc=2.9072, l_alloc=2.0069
# Outputs:
#  Utility=1.4622
#  Total Loss=-10.3845, VAE Loss=1.3510, IC Loss=0.2234, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-11.9591
# --------------------------------------------------
# [Epoch 302, Episode 1]
# Inputs:
#  R=471.3708, M=520.8213, Z=-0.0356, mean_k=50.8140, mean_theta=0.8452
#  region_obs mean=0.0642, std=1.0176
# Parameters (allocations):
#  c_alloc_mean=2.9829, x_alloc_mean=2.9024, l_alloc_mean=2.0041
#  c_alloc=2.9856, x_alloc=2.9077, l_alloc=2.0052
# Outputs:
#  Utility=1.0410
#  Total Loss=-0.2610, VAE Loss=1.1489, IC Loss=0.9788, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-2.3889
# --------------------------------------------------
# [Epoch 302, Episode 2]
# Inputs:
#  R=472.1141, M=517.8627, Z=-0.0727, mean_k=50.7165, mean_theta=0.6323
#  region_obs mean=0.1608, std=1.0328
# Parameters (allocations):
#  c_alloc_mean=2.9857, x_alloc_mean=2.8696, l_alloc_mean=2.0041
#  c_alloc=2.9831, x_alloc=2.8737, l_alloc=2.0007
# Outputs:
#  Utility=0.7946
#  Total Loss=9.5297, VAE Loss=1.0732, IC Loss=1.3522, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=7.1042
# --------------------------------------------------
# [Epoch 303, Episode 1]
# Inputs:
#  R=471.7918, M=517.9135, Z=-0.0240, mean_k=50.7807, mean_theta=0.7223
#  region_obs mean=0.0370, std=0.9934
# Parameters (allocations):
#  c_alloc_mean=2.9824, x_alloc_mean=2.9189, l_alloc_mean=2.0041
#  c_alloc=2.9728, x_alloc=2.9144, l_alloc=2.0029
# Outputs:
#  Utility=1.1575
#  Total Loss=2.8695, VAE Loss=1.0750, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=1.7942
# --------------------------------------------------
# [Epoch 303, Episode 2]
# Inputs:
#  R=472.7664, M=522.5988, Z=0.0251, mean_k=50.6397, mean_theta=1.0412
#  region_obs mean=-0.3016, std=1.0053
# Parameters (allocations):
#  c_alloc_mean=2.9864, x_alloc_mean=2.8982, l_alloc_mean=2.0041
#  c_alloc=2.9769, x_alloc=2.9007, l_alloc=2.0074
# Outputs:
#  Utility=1.2264
#  Total Loss=-11.7979, VAE Loss=1.2727, IC Loss=0.6986, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-13.7694
# --------------------------------------------------
# [Epoch 304, Episode 1]
# Inputs:
#  R=469.9282, M=515.9665, Z=-0.0055, mean_k=51.0531, mean_theta=0.5204
#  region_obs mean=-0.3481, std=0.8305
# Parameters (allocations):
#  c_alloc_mean=2.9817, x_alloc_mean=2.9009, l_alloc_mean=2.0041
#  c_alloc=2.9773, x_alloc=2.8965, l_alloc=2.0045
# Outputs:
#  Utility=1.0587
#  Total Loss=1.9321, VAE Loss=0.9272, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=1.0045
# --------------------------------------------------
# [Epoch 304, Episode 2]
# Inputs:
#  R=471.7149, M=520.5848, Z=-0.0270, mean_k=50.7507, mean_theta=1.2276
#  region_obs mean=0.0854, std=0.9598
# Parameters (allocations):
#  c_alloc_mean=2.9900, x_alloc_mean=2.8746, l_alloc_mean=2.0041
#  c_alloc=2.9934, x_alloc=2.8757, l_alloc=2.0100
# Outputs:
#  Utility=1.4607
#  Total Loss=8.6478, VAE Loss=1.0411, IC Loss=0.1714, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=7.4351
# --------------------------------------------------
# [Epoch 305, Episode 1]
# Inputs:
#  R=469.0712, M=514.9040, Z=0.0285, mean_k=51.1782, mean_theta=0.4427
#  region_obs mean=-0.1669, std=0.8656
# Parameters (allocations):
#  c_alloc_mean=2.9845, x_alloc_mean=2.9187, l_alloc_mean=2.0041
#  c_alloc=2.9834, x_alloc=2.9162, l_alloc=2.0157
# Outputs:
#  Utility=0.8693
#  Total Loss=-9.8596, VAE Loss=0.9099, IC Loss=0.0690, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-10.8388
# --------------------------------------------------
# [Epoch 305, Episode 2]
# Inputs:
#  R=470.7041, M=513.8771, Z=0.0632, mean_k=50.9527, mean_theta=0.6577
#  region_obs mean=0.0220, std=1.0520
# Parameters (allocations):
#  c_alloc_mean=2.9826, x_alloc_mean=2.8622, l_alloc_mean=2.0041
#  c_alloc=2.9784, x_alloc=2.8680, l_alloc=2.0048
# Outputs:
#  Utility=1.2048
#  Total Loss=4.4213, VAE Loss=1.1711, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=3.2500
# --------------------------------------------------
# [Epoch 306, Episode 1]
# Inputs:
#  R=471.4115, M=521.8907, Z=-0.0245, mean_k=50.8005, mean_theta=0.7228
#  region_obs mean=0.0099, std=1.1639
# Parameters (allocations):
#  c_alloc_mean=2.9852, x_alloc_mean=2.8836, l_alloc_mean=2.0041
#  c_alloc=2.9875, x_alloc=2.8870, l_alloc=2.0110
# Outputs:
#  Utility=1.2634
#  Total Loss=1.6874, VAE Loss=1.5813, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=0.1059
# --------------------------------------------------
# [Epoch 306, Episode 2]
# Inputs:
#  R=471.0493, M=521.9171, Z=0.0304, mean_k=50.8716, mean_theta=0.7682
#  region_obs mean=-0.3027, std=1.0351
# Parameters (allocations):
#  c_alloc_mean=2.9841, x_alloc_mean=2.8796, l_alloc_mean=2.0041
#  c_alloc=2.9800, x_alloc=2.8891, l_alloc=2.0058
# Outputs:
#  Utility=1.2375
#  Total Loss=11.9831, VAE Loss=1.1772, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=10.8056
# --------------------------------------------------
# [Epoch 307, Episode 1]
# Inputs:
#  R=471.4505, M=516.8511, Z=0.0469, mean_k=50.8268, mean_theta=0.5744
#  region_obs mean=-0.1178, std=1.1080
# Parameters (allocations):
#  c_alloc_mean=2.9823, x_alloc_mean=2.8932, l_alloc_mean=2.0041
#  c_alloc=2.9732, x_alloc=2.8993, l_alloc=2.0046
# Outputs:
#  Utility=0.9533
#  Total Loss=-3.5935, VAE Loss=1.3878, IC Loss=0.2400, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=-5.2217
# --------------------------------------------------
# [Epoch 307, Episode 2]
# Inputs:
#  R=471.6457, M=523.9755, Z=0.0534, mean_k=50.7772, mean_theta=0.9113
#  region_obs mean=0.2870, std=0.9660
# Parameters (allocations):
#  c_alloc_mean=2.9898, x_alloc_mean=2.8831, l_alloc_mean=2.0041
#  c_alloc=2.9906, x_alloc=2.8861, l_alloc=2.0062
# Outputs:
#  Utility=1.2138
#  Total Loss=7.0900, VAE Loss=1.1662, IC Loss=0.3428, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=5.5807
# --------------------------------------------------
# [Epoch 308, Episode 1]
# Inputs:
#  R=471.6507, M=521.6144, Z=0.0431, mean_k=50.8032, mean_theta=0.8035
#  region_obs mean=0.2401, std=0.9380
# Parameters (allocations):
#  c_alloc_mean=2.9867, x_alloc_mean=2.9083, l_alloc_mean=2.0041
#  c_alloc=2.9866, x_alloc=2.9131, l_alloc=2.0074
# Outputs:
#  Utility=1.3672
#  Total Loss=15.2933, VAE Loss=1.0840, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=14.2091
# --------------------------------------------------
# [Epoch 308, Episode 2]
# Inputs:
#  R=471.4930, M=521.6281, Z=-0.0345, mean_k=50.8302, mean_theta=0.6640
#  region_obs mean=0.0524, std=0.9407
# Parameters (allocations):
#  c_alloc_mean=2.9838, x_alloc_mean=2.8844, l_alloc_mean=2.0041
#  c_alloc=2.9861, x_alloc=2.8823, l_alloc=2.0108
# Outputs:
#  Utility=1.0103
#  Total Loss=-11.1927, VAE Loss=0.9510, IC Loss=0.3527, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-12.4967
# --------------------------------------------------
# [Epoch 309, Episode 1]
# Inputs:
#  R=470.1173, M=519.8587, Z=0.0072, mean_k=51.0069, mean_theta=0.7986
#  region_obs mean=0.1620, std=0.9781
# Parameters (allocations):
#  c_alloc_mean=2.9878, x_alloc_mean=2.8836, l_alloc_mean=2.0041
#  c_alloc=2.9859, x_alloc=2.8814, l_alloc=2.0042
# Outputs:
#  Utility=1.4193
#  Total Loss=6.7884, VAE Loss=1.0854, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=5.7028
# --------------------------------------------------
# [Epoch 309, Episode 2]
# Inputs:
#  R=471.5411, M=519.2413, Z=0.0086, mean_k=50.8196, mean_theta=0.6220
#  region_obs mean=0.1038, std=1.1088
# Parameters (allocations):
#  c_alloc_mean=2.9852, x_alloc_mean=2.8986, l_alloc_mean=2.0041
#  c_alloc=2.9767, x_alloc=2.9004, l_alloc=2.0065
# Outputs:
#  Utility=0.8213
#  Total Loss=-4.1524, VAE Loss=1.4891, IC Loss=1.1670, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-6.8087
# --------------------------------------------------
# [Epoch 310, Episode 1]
# Inputs:
#  R=470.6118, M=512.5002, Z=0.0107, mean_k=50.9572, mean_theta=0.4996
#  region_obs mean=0.0477, std=0.9356
# Parameters (allocations):
#  c_alloc_mean=2.9835, x_alloc_mean=2.8758, l_alloc_mean=2.0041
#  c_alloc=2.9814, x_alloc=2.8802, l_alloc=2.0047
# Outputs:
#  Utility=0.8139
#  Total Loss=5.8710, VAE Loss=0.9090, IC Loss=0.6212, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=4.3406
# --------------------------------------------------
# [Epoch 310, Episode 2]
# Inputs:
#  R=472.2292, M=518.1724, Z=-0.0754, mean_k=50.6988, mean_theta=0.9112
#  region_obs mean=-0.3473, std=1.0049
# Parameters (allocations):
#  c_alloc_mean=2.9806, x_alloc_mean=2.9036, l_alloc_mean=2.0041
#  c_alloc=2.9749, x_alloc=2.8984, l_alloc=2.0071
# Outputs:
#  Utility=1.3483
#  Total Loss=-2.4682, VAE Loss=1.0801, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=-3.5486
# --------------------------------------------------
# [Epoch 311, Episode 1]
# Inputs:
#  R=472.4059, M=522.8724, Z=-0.0398, mean_k=50.6775, mean_theta=0.8374
#  region_obs mean=0.0033, std=1.0076
# Parameters (allocations):
#  c_alloc_mean=2.9833, x_alloc_mean=2.8937, l_alloc_mean=2.0041
#  c_alloc=2.9810, x_alloc=2.8982, l_alloc=2.0040
# Outputs:
#  Utility=1.2292
#  Total Loss=1.2007, VAE Loss=1.1238, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=0.0765
# --------------------------------------------------
# [Epoch 311, Episode 2]
# Inputs:
#  R=471.1660, M=517.9888, Z=-0.0190, mean_k=50.8660, mean_theta=0.6903
#  region_obs mean=0.1254, std=1.0099
# Parameters (allocations):
#  c_alloc_mean=2.9816, x_alloc_mean=2.8860, l_alloc_mean=2.0041
#  c_alloc=2.9769, x_alloc=2.8864, l_alloc=2.0075
# Outputs:
#  Utility=1.0385
#  Total Loss=12.5982, VAE Loss=1.1136, IC Loss=0.3415, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=11.1427
# --------------------------------------------------
# [Epoch 312, Episode 1]
# Inputs:
#  R=470.9661, M=523.6361, Z=0.0185, mean_k=50.8888, mean_theta=0.9345
#  region_obs mean=-0.0815, std=1.0163
# Parameters (allocations):
#  c_alloc_mean=2.9866, x_alloc_mean=2.8900, l_alloc_mean=2.0041
#  c_alloc=2.9982, x_alloc=2.8885, l_alloc=2.0120
# Outputs:
#  Utility=1.4230
#  Total Loss=-4.4403, VAE Loss=1.2656, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-5.7060
# --------------------------------------------------
# [Epoch 312, Episode 2]
# Inputs:
#  R=470.1649, M=519.4468, Z=-0.0416, mean_k=51.0075, mean_theta=0.7522
#  region_obs mean=0.0212, std=1.0783
# Parameters (allocations):
#  c_alloc_mean=2.9826, x_alloc_mean=2.8786, l_alloc_mean=2.0041
#  c_alloc=2.9845, x_alloc=2.8877, l_alloc=2.0074
# Outputs:
#  Utility=0.6899
#  Total Loss=6.0124, VAE Loss=1.2576, IC Loss=2.3389, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=2.4156
# --------------------------------------------------
# [Epoch 313, Episode 1]
# Inputs:
#  R=471.9212, M=522.1852, Z=0.0168, mean_k=50.7548, mean_theta=1.0991
#  region_obs mean=-0.0582, std=1.1030
# Parameters (allocations):
#  c_alloc_mean=2.9812, x_alloc_mean=2.8936, l_alloc_mean=2.0041
#  c_alloc=2.9793, x_alloc=2.8894, l_alloc=2.0085
# Outputs:
#  Utility=1.1243
#  Total Loss=3.5407, VAE Loss=1.2836, IC Loss=1.5145, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=0.7423
# --------------------------------------------------
# [Epoch 313, Episode 2]
# Inputs:
#  R=471.5802, M=529.9243, Z=0.0034, mean_k=50.7955, mean_theta=1.3240
#  region_obs mean=0.0883, std=1.1080
# Parameters (allocations):
#  c_alloc_mean=2.9872, x_alloc_mean=2.8884, l_alloc_mean=2.0041
#  c_alloc=2.9897, x_alloc=2.8927, l_alloc=2.0016
# Outputs:
#  Utility=1.3544
#  Total Loss=-7.3476, VAE Loss=1.3810, IC Loss=0.9471, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-9.6760
# --------------------------------------------------
# [Epoch 314, Episode 1]
# Inputs:
#  R=471.1107, M=522.7784, Z=-0.0116, mean_k=50.8834, mean_theta=0.8621
#  region_obs mean=0.2817, std=1.1138
# Parameters (allocations):
#  c_alloc_mean=2.9845, x_alloc_mean=2.8896, l_alloc_mean=2.0041
#  c_alloc=2.9911, x_alloc=2.8887, l_alloc=2.0032
# Outputs:
#  Utility=1.1463
#  Total Loss=7.2769, VAE Loss=1.4310, IC Loss=0.4477, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=5.3980
# --------------------------------------------------
# [Epoch 314, Episode 2]
# Inputs:
#  R=472.0554, M=517.8415, Z=-0.0102, mean_k=50.7281, mean_theta=0.9840
#  region_obs mean=0.2359, std=0.9802
# Parameters (allocations):
#  c_alloc_mean=2.9828, x_alloc_mean=2.8989, l_alloc_mean=2.0041
#  c_alloc=2.9853, x_alloc=2.8931, l_alloc=2.0082
# Outputs:
#  Utility=1.3873
#  Total Loss=7.2874, VAE Loss=1.0817, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=6.2054
# --------------------------------------------------
# [Epoch 315, Episode 1]
# Inputs:
#  R=471.8378, M=520.0297, Z=0.0055, mean_k=50.7684, mean_theta=0.7333
#  region_obs mean=-0.1309, std=1.0613
# Parameters (allocations):
#  c_alloc_mean=2.9881, x_alloc_mean=2.8898, l_alloc_mean=2.0041
#  c_alloc=2.9897, x_alloc=2.8912, l_alloc=2.0072
# Outputs:
#  Utility=0.9232
#  Total Loss=2.9681, VAE Loss=1.2605, IC Loss=1.0784, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=0.6288
# --------------------------------------------------
# [Epoch 315, Episode 2]
# Inputs:
#  R=471.3975, M=523.9257, Z=0.0351, mean_k=50.8219, mean_theta=0.9798
#  region_obs mean=0.3188, std=1.0256
# Parameters (allocations):
#  c_alloc_mean=2.9848, x_alloc_mean=2.8867, l_alloc_mean=2.0041
#  c_alloc=2.9782, x_alloc=2.8802, l_alloc=2.0069
# Outputs:
#  Utility=1.1954
#  Total Loss=-2.0746, VAE Loss=1.2557, IC Loss=0.6489, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-3.9795
# --------------------------------------------------
# [Epoch 316, Episode 1]
# Inputs:
#  R=470.5353, M=524.9995, Z=-0.0200, mean_k=50.9348, mean_theta=0.7983
#  region_obs mean=-0.1548, std=1.0642
# Parameters (allocations):
#  c_alloc_mean=2.9854, x_alloc_mean=2.9092, l_alloc_mean=2.0041
#  c_alloc=2.9886, x_alloc=2.9107, l_alloc=2.0140
# Outputs:
#  Utility=0.8658
#  Total Loss=6.2936, VAE Loss=1.3438, IC Loss=1.6705, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=3.2791
# --------------------------------------------------
# [Epoch 316, Episode 2]
# Inputs:
#  R=471.8590, M=525.4807, Z=-0.0027, mean_k=50.7571, mean_theta=1.0530
#  region_obs mean=-0.2493, std=0.9200
# Parameters (allocations):
#  c_alloc_mean=2.9893, x_alloc_mean=2.8639, l_alloc_mean=2.0041
#  c_alloc=2.9912, x_alloc=2.8590, l_alloc=2.0002
# Outputs:
#  Utility=1.3643
#  Total Loss=10.2994, VAE Loss=1.0377, IC Loss=0.0602, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=9.2013
# --------------------------------------------------
# [Epoch 317, Episode 1]
# Inputs:
#  R=471.8881, M=519.1986, Z=0.0388, mean_k=50.7785, mean_theta=0.7928
#  region_obs mean=-0.0185, std=0.9975
# Parameters (allocations):
#  c_alloc_mean=2.9862, x_alloc_mean=2.8713, l_alloc_mean=2.0041
#  c_alloc=2.9891, x_alloc=2.8720, l_alloc=2.0106
# Outputs:
#  Utility=1.0334
#  Total Loss=-0.6381, VAE Loss=1.0592, IC Loss=0.7190, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-2.4166
# --------------------------------------------------
# [Epoch 317, Episode 2]
# Inputs:
#  R=470.6164, M=520.7977, Z=-0.0718, mean_k=50.9383, mean_theta=1.3044
#  region_obs mean=-0.1283, std=1.1231
# Parameters (allocations):
#  c_alloc_mean=2.9830, x_alloc_mean=2.8916, l_alloc_mean=2.0041
#  c_alloc=2.9828, x_alloc=2.8964, l_alloc=2.0049
# Outputs:
#  Utility=1.6891
#  Total Loss=15.4669, VAE Loss=1.4374, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=14.0293
# --------------------------------------------------
# [Epoch 318, Episode 1]
# Inputs:
#  R=472.1689, M=516.6470, Z=-0.0099, mean_k=50.7179, mean_theta=0.6125
#  region_obs mean=0.2638, std=1.0255
# Parameters (allocations):
#  c_alloc_mean=2.9807, x_alloc_mean=2.8794, l_alloc_mean=2.0041
#  c_alloc=2.9804, x_alloc=2.8802, l_alloc=1.9993
# Outputs:
#  Utility=0.7628
#  Total Loss=5.4244, VAE Loss=1.1986, IC Loss=1.4280, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=2.7974
# --------------------------------------------------
# [Epoch 318, Episode 2]
# Inputs:
#  R=470.1460, M=521.0792, Z=0.0710, mean_k=50.9926, mean_theta=0.8666
#  region_obs mean=-0.1507, std=1.0810
# Parameters (allocations):
#  c_alloc_mean=2.9855, x_alloc_mean=2.8935, l_alloc_mean=2.0041
#  c_alloc=2.9925, x_alloc=2.8976, l_alloc=2.0031
# Outputs:
#  Utility=1.1857
#  Total Loss=-0.6190, VAE Loss=1.3781, IC Loss=0.2929, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-2.2901
# --------------------------------------------------
# [Epoch 319, Episode 1]
# Inputs:
#  R=471.5719, M=518.5839, Z=-0.0380, mean_k=50.7844, mean_theta=0.7165
#  region_obs mean=0.0231, std=0.8943
# Parameters (allocations):
#  c_alloc_mean=2.9871, x_alloc_mean=2.9028, l_alloc_mean=2.0041
#  c_alloc=2.9871, x_alloc=2.8975, l_alloc=2.0019
# Outputs:
#  Utility=1.2686
#  Total Loss=1.1801, VAE Loss=0.8152, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=0.3646
# --------------------------------------------------
# [Epoch 319, Episode 2]
# Inputs:
#  R=471.4881, M=527.9463, Z=0.0125, mean_k=50.7909, mean_theta=1.5350
#  region_obs mean=0.0379, std=1.0218
# Parameters (allocations):
#  c_alloc_mean=2.9909, x_alloc_mean=2.8867, l_alloc_mean=2.0041
#  c_alloc=2.9927, x_alloc=2.8840, l_alloc=2.0080
# Outputs:
#  Utility=1.6310
#  Total Loss=4.9836, VAE Loss=1.0950, IC Loss=0.1802, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=3.7083
# --------------------------------------------------
# [Epoch 320, Episode 1]
# Inputs:
#  R=470.8038, M=524.0880, Z=-0.0114, mean_k=50.9330, mean_theta=1.0848
#  region_obs mean=0.2170, std=1.1657
# Parameters (allocations):
#  c_alloc_mean=2.9832, x_alloc_mean=2.8936, l_alloc_mean=2.0041
#  c_alloc=2.9865, x_alloc=2.9012, l_alloc=2.0013
# Outputs:
#  Utility=1.0448
#  Total Loss=6.7958, VAE Loss=1.5794, IC Loss=1.7317, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=3.4843
# --------------------------------------------------
# [Epoch 320, Episode 2]
# Inputs:
#  R=471.7553, M=523.1810, Z=-0.0057, mean_k=50.7884, mean_theta=0.6729
#  region_obs mean=-0.0241, std=1.0513
# Parameters (allocations):
#  c_alloc_mean=2.9905, x_alloc_mean=2.8846, l_alloc_mean=2.0041
#  c_alloc=2.9896, x_alloc=2.8848, l_alloc=2.0004
# Outputs:
#  Utility=1.0502
#  Total Loss=-3.1206, VAE Loss=1.3090, IC Loss=0.1562, IR Loss=0.0000, Ostrom Loss=0.0001, Resource Loss=0.0000, Policy Loss=-4.5859
# --------------------------------------------------
# [Epoch 321, Episode 1]
# Inputs:
#  R=473.4460, M=519.0001, Z=-0.0035, mean_k=50.5161, mean_theta=1.3987
#  region_obs mean=-0.1782, std=0.7853
# Parameters (allocations):
#  c_alloc_mean=2.9823, x_alloc_mean=2.8871, l_alloc_mean=2.0041
#  c_alloc=2.9871, x_alloc=2.8887, l_alloc=2.0037
# Outputs:
#  Utility=1.8870
#  Total Loss=4.1594, VAE Loss=0.7276, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=3.4314
# --------------------------------------------------
# [Epoch 321, Episode 2]
# Inputs:
#  R=473.5475, M=523.7551, Z=0.0247, mean_k=50.5233, mean_theta=1.2383
#  region_obs mean=0.0373, std=0.9866
# Parameters (allocations):
#  c_alloc_mean=2.9844, x_alloc_mean=2.8872, l_alloc_mean=2.0041
#  c_alloc=2.9760, x_alloc=2.8904, l_alloc=2.0096
# Outputs:
#  Utility=1.5379
#  Total Loss=-4.7659, VAE Loss=1.0544, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-5.8205
# --------------------------------------------------
# [Epoch 322, Episode 1]
# Inputs:
#  R=472.4211, M=521.8953, Z=0.0784, mean_k=50.6638, mean_theta=0.8137
#  region_obs mean=-0.0686, std=0.9460
# Parameters (allocations):
#  c_alloc_mean=2.9850, x_alloc_mean=2.8678, l_alloc_mean=2.0041
#  c_alloc=2.9850, x_alloc=2.8682, l_alloc=2.0000
# Outputs:
#  Utility=0.9776
#  Total Loss=6.0122, VAE Loss=1.0418, IC Loss=1.1213, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=3.8490
# --------------------------------------------------
# [Epoch 322, Episode 2]
# Inputs:
#  R=471.8405, M=524.5479, Z=-0.0808, mean_k=50.7252, mean_theta=1.0464
#  region_obs mean=-0.0082, std=0.9406
# Parameters (allocations):
#  c_alloc_mean=2.9922, x_alloc_mean=2.9104, l_alloc_mean=2.0041
#  c_alloc=2.9969, x_alloc=2.9054, l_alloc=2.0107
# Outputs:
#  Utility=1.2456
#  Total Loss=8.0951, VAE Loss=0.9765, IC Loss=0.6295, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=6.4889
# --------------------------------------------------
# [Epoch 323, Episode 1]
# Inputs:
#  R=472.5442, M=521.4904, Z=0.0498, mean_k=50.6689, mean_theta=1.3150
#  region_obs mean=-0.0991, std=1.0197
# Parameters (allocations):
#  c_alloc_mean=2.9848, x_alloc_mean=2.9229, l_alloc_mean=2.0041
#  c_alloc=2.9787, x_alloc=2.9199, l_alloc=2.0046
# Outputs:
#  Utility=1.6271
#  Total Loss=-7.8198, VAE Loss=1.1769, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-8.9970
# --------------------------------------------------
# [Epoch 323, Episode 2]
# Inputs:
#  R=471.7802, M=526.1540, Z=0.0037, mean_k=50.7303, mean_theta=1.3756
# ...
# [Epoch 484, Episode 2]
# Inputs:
#  R=472.9089, M=521.9368, Z=0.0104, mean_k=50.5609, mean_theta=0.8449
#  region_obs mean=-0.0979, std=0.9857
# Parameters (allocations):
#  c_alloc_mean=2.9817, x_alloc_mean=2.8390, l_alloc_mean=2.0041
#  c_alloc=2.9855, x_alloc=2.8434, l_alloc=2.0029
# Outputs:
#  Utility=1.2000
#  Total Loss=17.3775, VAE Loss=1.0949, IC Loss=0.1322, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=16.1501
# --------------------------------------------------
# [Epoch 485, Episode 1]
# Inputs:
#  R=472.7975, M=520.3434, Z=0.0674, mean_k=50.5968, mean_theta=0.8146
#  region_obs mean=0.0098, std=0.8928
# Parameters (allocations):
#  c_alloc_mean=2.9855, x_alloc_mean=2.8544, l_alloc_mean=2.0041
#  c_alloc=2.9869, x_alloc=2.8528, l_alloc=2.0034
# Outputs:
#  Utility=1.3384
#  Total Loss=2.9740, VAE Loss=0.9477, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=2.0260
# --------------------------------------------------
# [Epoch 485, Episode 2]
# Inputs:
#  R=473.4075, M=519.8763, Z=-0.0236, mean_k=50.5311, mean_theta=1.0688
#  region_obs mean=-0.0149, std=1.0515
# Parameters (allocations):
#  c_alloc_mean=2.9817, x_alloc_mean=2.8368, l_alloc_mean=2.0041
#  c_alloc=2.9686, x_alloc=2.8384, l_alloc=2.0038
# Outputs:
#  Utility=1.3317
#  Total Loss=-10.7926, VAE Loss=1.2247, IC Loss=0.2579, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=-12.2756
# --------------------------------------------------
# [Epoch 486, Episode 1]
# Inputs:
#  R=470.8946, M=515.0634, Z=-0.0181, mean_k=50.9049, mean_theta=0.2816
#  region_obs mean=0.1361, std=0.9300
# Parameters (allocations):
#  c_alloc_mean=2.9827, x_alloc_mean=2.8759, l_alloc_mean=2.0041
#  c_alloc=2.9862, x_alloc=2.8719, l_alloc=2.0024
# Outputs:
#  Utility=0.7352
#  Total Loss=-17.4062, VAE Loss=1.0288, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-18.4352
# --------------------------------------------------
# [Epoch 486, Episode 2]
# Inputs:
#  R=471.6641, M=525.3225, Z=-0.0093, mean_k=50.7719, mean_theta=1.1212
#  region_obs mean=0.0027, std=1.0017
# Parameters (allocations):
#  c_alloc_mean=2.9861, x_alloc_mean=2.8940, l_alloc_mean=2.0041
#  c_alloc=2.9855, x_alloc=2.8896, l_alloc=2.0035
# Outputs:
#  Utility=1.2938
#  Total Loss=0.1433, VAE Loss=1.1974, IC Loss=0.6404, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-1.6947
# --------------------------------------------------
# [Epoch 487, Episode 1]
# Inputs:
#  R=472.5030, M=520.7657, Z=0.0339, mean_k=50.6499, mean_theta=0.4808
#  region_obs mean=-0.1983, std=1.0398
# Parameters (allocations):
#  c_alloc_mean=2.9867, x_alloc_mean=2.8535, l_alloc_mean=2.0041
#  c_alloc=2.9824, x_alloc=2.8537, l_alloc=2.0094
# Outputs:
#  Utility=0.8651
#  Total Loss=-8.0831, VAE Loss=1.2651, IC Loss=0.2796, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-9.6281
# --------------------------------------------------
# [Epoch 487, Episode 2]
# Inputs:
#  R=471.7648, M=522.7515, Z=0.0266, mean_k=50.7442, mean_theta=1.3859
#  region_obs mean=0.0356, std=1.0008
# Parameters (allocations):
#  c_alloc_mean=2.9875, x_alloc_mean=2.8857, l_alloc_mean=2.0041
#  c_alloc=2.9838, x_alloc=2.8817, l_alloc=1.9998
# Outputs:
#  Utility=1.5074
#  Total Loss=-4.5701, VAE Loss=0.9723, IC Loss=0.4103, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-5.9529
# --------------------------------------------------
# [Epoch 488, Episode 1]
# Inputs:
#  R=471.1851, M=525.3761, Z=0.0239, mean_k=50.8542, mean_theta=1.3941
#  region_obs mean=0.2014, std=0.9571
# Parameters (allocations):
#  c_alloc_mean=2.9857, x_alloc_mean=2.8925, l_alloc_mean=2.0041
#  c_alloc=2.9863, x_alloc=2.8881, l_alloc=2.0054
# Outputs:
#  Utility=1.4232
#  Total Loss=-2.0894, VAE Loss=1.0115, IC Loss=0.7610, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-3.8621
# --------------------------------------------------
# [Epoch 488, Episode 2]
# Inputs:
#  R=472.2186, M=519.4540, Z=-0.0002, mean_k=50.6985, mean_theta=0.5315
#  region_obs mean=-0.0872, std=1.1960
# Parameters (allocations):
#  c_alloc_mean=2.9795, x_alloc_mean=2.8569, l_alloc_mean=2.0041
#  c_alloc=2.9797, x_alloc=2.8607, l_alloc=2.0042
# Outputs:
#  Utility=0.8404
#  Total Loss=-5.8223, VAE Loss=1.3808, IC Loss=0.6262, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=-7.8297
# --------------------------------------------------
# [Epoch 489, Episode 1]
# Inputs:
#  R=471.7407, M=514.1871, Z=0.0334, mean_k=50.8017, mean_theta=0.4068
#  region_obs mean=-0.1976, std=0.8502
# Parameters (allocations):
#  c_alloc_mean=2.9701, x_alloc_mean=2.9249, l_alloc_mean=2.0041
#  c_alloc=2.9676, x_alloc=2.9289, l_alloc=2.0031
# Outputs:
#  Utility=0.6846
#  Total Loss=7.0679, VAE Loss=0.8436, IC Loss=0.8014, IR Loss=0.0000, Ostrom Loss=0.0006, Resource Loss=0.0000, Policy Loss=5.4222
# --------------------------------------------------
# [Epoch 489, Episode 2]
# Inputs:
#  R=472.3848, M=517.3411, Z=-0.0028, mean_k=50.6929, mean_theta=0.7199
#  region_obs mean=-0.0413, std=0.8736
# Parameters (allocations):
#  c_alloc_mean=2.9771, x_alloc_mean=2.8512, l_alloc_mean=2.0041
#  c_alloc=2.9796, x_alloc=2.8574, l_alloc=2.0076
# Outputs:
#  Utility=1.0470
#  Total Loss=-3.1505, VAE Loss=0.8114, IC Loss=0.4302, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=-4.3926
# --------------------------------------------------
# [Epoch 490, Episode 1]
# Inputs:
#  R=471.7278, M=523.1062, Z=0.0067, mean_k=50.7553, mean_theta=1.2014
#  region_obs mean=-0.0746, std=1.0258
# Parameters (allocations):
#  c_alloc_mean=2.9892, x_alloc_mean=2.9250, l_alloc_mean=2.0041
#  c_alloc=2.9931, x_alloc=2.9319, l_alloc=2.0014
# Outputs:
#  Utility=1.5662
#  Total Loss=-8.0832, VAE Loss=1.1686, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-9.2520
# --------------------------------------------------
# [Epoch 490, Episode 2]
# Inputs:
#  R=472.9208, M=522.6925, Z=-0.0428, mean_k=50.6110, mean_theta=1.2047
#  region_obs mean=0.2859, std=1.0051
# Parameters (allocations):
#  c_alloc_mean=2.9902, x_alloc_mean=2.8948, l_alloc_mean=2.0041
#  c_alloc=2.9931, x_alloc=2.8956, l_alloc=2.0091
# Outputs:
#  Utility=1.2745
#  Total Loss=7.8796, VAE Loss=1.0886, IC Loss=0.9779, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=5.8129
# --------------------------------------------------
# [Epoch 491, Episode 1]
# Inputs:
#  R=473.4338, M=525.7458, Z=0.0439, mean_k=50.5385, mean_theta=1.1995
#  region_obs mean=0.2581, std=0.9125
# Parameters (allocations):
#  c_alloc_mean=2.9827, x_alloc_mean=2.8879, l_alloc_mean=2.0041
#  c_alloc=2.9846, x_alloc=2.8877, l_alloc=2.0069
# Outputs:
#  Utility=1.4746
#  Total Loss=4.8472, VAE Loss=1.0278, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=3.8191
# --------------------------------------------------
# [Epoch 491, Episode 2]
# Inputs:
#  R=471.7271, M=516.8033, Z=0.0221, mean_k=50.8057, mean_theta=0.4357
#  region_obs mean=-0.2728, std=1.0713
# Parameters (allocations):
#  c_alloc_mean=2.9798, x_alloc_mean=2.8861, l_alloc_mean=2.0041
#  c_alloc=2.9834, x_alloc=2.8889, l_alloc=2.0036
# Outputs:
#  Utility=0.9067
#  Total Loss=4.2006, VAE Loss=1.3467, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=2.8536
# --------------------------------------------------
# [Epoch 492, Episode 1]
# Inputs:
#  R=471.8187, M=519.0261, Z=-0.0072, mean_k=50.7760, mean_theta=0.6581
#  region_obs mean=-0.0002, std=1.0226
# Parameters (allocations):
#  c_alloc_mean=2.9856, x_alloc_mean=2.8931, l_alloc_mean=2.0041
#  c_alloc=2.9860, x_alloc=2.8928, l_alloc=2.0056
# Outputs:
#  Utility=1.1363
#  Total Loss=11.1575, VAE Loss=1.1642, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=9.9931
# --------------------------------------------------
# [Epoch 492, Episode 2]
# Inputs:
#  R=471.6852, M=518.1661, Z=0.0266, mean_k=50.7965, mean_theta=0.5510
#  region_obs mean=-0.2767, std=0.9332
# Parameters (allocations):
#  c_alloc_mean=2.9809, x_alloc_mean=2.9030, l_alloc_mean=2.0041
#  c_alloc=2.9813, x_alloc=2.9047, l_alloc=2.0088
# Outputs:
#  Utility=1.0126
#  Total Loss=0.2655, VAE Loss=1.0460, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=-0.7808
# --------------------------------------------------
# [Epoch 493, Episode 1]
# Inputs:
#  R=473.7842, M=518.0801, Z=-0.0238, mean_k=50.4556, mean_theta=1.0026
#  region_obs mean=0.0966, std=1.0710
# Parameters (allocations):
#  c_alloc_mean=2.9807, x_alloc_mean=2.8763, l_alloc_mean=2.0041
#  c_alloc=2.9849, x_alloc=2.8725, l_alloc=2.0122
# Outputs:
#  Utility=1.2520
#  Total Loss=-3.7964, VAE Loss=1.2675, IC Loss=0.4495, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-5.5136
# --------------------------------------------------
# [Epoch 493, Episode 2]
# Inputs:
#  R=474.0570, M=521.6296, Z=-0.0803, mean_k=50.4451, mean_theta=1.0361
#  region_obs mean=0.0136, std=1.0126
# Parameters (allocations):
#  c_alloc_mean=2.9828, x_alloc_mean=2.8728, l_alloc_mean=2.0041
#  c_alloc=2.9881, x_alloc=2.8810, l_alloc=2.0053
# Outputs:
#  Utility=1.0857
#  Total Loss=-8.7488, VAE Loss=1.1892, IC Loss=1.3810, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-11.3192
# --------------------------------------------------
# [Epoch 494, Episode 1]
# Inputs:
#  R=472.6029, M=525.4025, Z=0.0420, mean_k=50.6500, mean_theta=1.0010
#  region_obs mean=-0.1079, std=1.0578
# Parameters (allocations):
#  c_alloc_mean=2.9847, x_alloc_mean=2.8363, l_alloc_mean=2.0041
#  c_alloc=2.9772, x_alloc=2.8413, l_alloc=2.0044
# Outputs:
#  Utility=1.3054
#  Total Loss=-2.9470, VAE Loss=1.1752, IC Loss=0.1259, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-4.2484
# --------------------------------------------------
# [Epoch 494, Episode 2]
# Inputs:
#  R=473.1899, M=523.6259, Z=-0.0450, mean_k=50.5479, mean_theta=0.9195
#  region_obs mean=0.0392, std=0.9719
# Parameters (allocations):
#  c_alloc_mean=2.9772, x_alloc_mean=2.8843, l_alloc_mean=2.0041
#  c_alloc=2.9753, x_alloc=2.8921, l_alloc=2.0034
# Outputs:
#  Utility=1.1721
#  Total Loss=-3.8255, VAE Loss=0.9423, IC Loss=0.5346, IR Loss=0.0000, Ostrom Loss=0.0005, Resource Loss=0.0000, Policy Loss=-5.3029
# --------------------------------------------------
# [Epoch 495, Episode 1]
# Inputs:
#  R=473.0401, M=524.7790, Z=0.0099, mean_k=50.5905, mean_theta=1.2115
#  region_obs mean=0.0342, std=1.0722
# Parameters (allocations):
#  c_alloc_mean=2.9824, x_alloc_mean=2.8906, l_alloc_mean=2.0041
#  c_alloc=2.9846, x_alloc=2.8919, l_alloc=2.0019
# Outputs:
#  Utility=1.2698
#  Total Loss=0.0179, VAE Loss=1.3043, IC Loss=1.0546, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=-2.3414
# --------------------------------------------------
# [Epoch 495, Episode 2]
# Inputs:
#  R=472.5078, M=513.4004, Z=0.0031, mean_k=50.6771, mean_theta=0.6579
#  region_obs mean=0.0196, std=1.0087
# Parameters (allocations):
#  c_alloc_mean=2.9720, x_alloc_mean=2.8949, l_alloc_mean=2.0041
#  c_alloc=2.9810, x_alloc=2.8904, l_alloc=2.0041
# Outputs:
#  Utility=1.0733
#  Total Loss=-3.0098, VAE Loss=1.0792, IC Loss=0.0841, IR Loss=0.0000, Ostrom Loss=0.0005, Resource Loss=0.0000, Policy Loss=-4.1736
# --------------------------------------------------
# [Epoch 496, Episode 1]
# Inputs:
#  R=472.3932, M=518.3425, Z=-0.0097, mean_k=50.6866, mean_theta=0.6110
#  region_obs mean=0.2407, std=0.9513
# Parameters (allocations):
#  c_alloc_mean=2.9707, x_alloc_mean=2.8814, l_alloc_mean=2.0041
#  c_alloc=2.9691, x_alloc=2.8848, l_alloc=2.0072
# Outputs:
#  Utility=0.7423
#  Total Loss=12.7127, VAE Loss=1.0450, IC Loss=1.5218, IR Loss=0.0000, Ostrom Loss=0.0006, Resource Loss=0.0000, Policy Loss=10.1453
# --------------------------------------------------
# [Epoch 496, Episode 2]
# Inputs:
#  R=472.7872, M=516.1367, Z=-0.0463, mean_k=50.6023, mean_theta=0.5504
#  region_obs mean=-0.1346, std=0.8708
# Parameters (allocations):
#  c_alloc_mean=2.9784, x_alloc_mean=2.8858, l_alloc_mean=2.0041
#  c_alloc=2.9802, x_alloc=2.8975, l_alloc=2.0058
# Outputs:
#  Utility=0.9252
#  Total Loss=-14.0578, VAE Loss=0.9137, IC Loss=0.3404, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-15.3122
# --------------------------------------------------
# [Epoch 497, Episode 1]
# Inputs:
#  R=474.2072, M=518.4995, Z=-0.0059, mean_k=50.3632, mean_theta=0.9017
#  region_obs mean=-0.2162, std=1.0390
# Parameters (allocations):
#  c_alloc_mean=2.9841, x_alloc_mean=2.8241, l_alloc_mean=2.0041
#  c_alloc=2.9854, x_alloc=2.8166, l_alloc=2.0034
# Outputs:
#  Utility=1.2962
#  Total Loss=7.0626, VAE Loss=1.2868, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=5.7755
# --------------------------------------------------
# [Epoch 497, Episode 2]
# Inputs:
#  R=471.8965, M=515.2427, Z=-0.0417, mean_k=50.7736, mean_theta=0.5864
#  region_obs mean=-0.0368, std=0.9260
# Parameters (allocations):
#  c_alloc_mean=2.9675, x_alloc_mean=2.8859, l_alloc_mean=2.0041
#  c_alloc=2.9678, x_alloc=2.8929, l_alloc=1.9953
# Outputs:
#  Utility=1.1546
#  Total Loss=-0.3341, VAE Loss=0.9247, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0006, Resource Loss=0.0000, Policy Loss=-1.2594
# --------------------------------------------------
# [Epoch 498, Episode 1]
# Inputs:
#  R=472.9922, M=521.6036, Z=0.0209, mean_k=50.5706, mean_theta=0.9483
#  region_obs mean=-0.4112, std=0.9063
# Parameters (allocations):
#  c_alloc_mean=2.9845, x_alloc_mean=2.8468, l_alloc_mean=2.0041
#  c_alloc=2.9855, x_alloc=2.8361, l_alloc=2.0012
# Outputs:
#  Utility=1.4987
#  Total Loss=-11.4673, VAE Loss=1.0144, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-12.4820
# --------------------------------------------------
# [Epoch 498, Episode 2]
# Inputs:
#  R=473.6310, M=525.5704, Z=-0.0124, mean_k=50.5077, mean_theta=1.5012
#  region_obs mean=-0.3761, std=0.8436
# Parameters (allocations):
#  c_alloc_mean=2.9795, x_alloc_mean=2.8798, l_alloc_mean=2.0041
#  c_alloc=2.9782, x_alloc=2.8822, l_alloc=2.0110
# Outputs:
#  Utility=1.6615
#  Total Loss=-2.1886, VAE Loss=0.9130, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=-3.1020
# --------------------------------------------------
# [Epoch 499, Episode 1]
# Inputs:
#  R=473.6785, M=522.7044, Z=0.0431, mean_k=50.4743, mean_theta=0.9974
#  region_obs mean=-0.0740, std=1.0836
# Parameters (allocations):
#  c_alloc_mean=2.9794, x_alloc_mean=2.8765, l_alloc_mean=2.0041
#  c_alloc=2.9742, x_alloc=2.8779, l_alloc=2.0069
# Outputs:
#  Utility=1.5555
#  Total Loss=3.9327, VAE Loss=1.1731, IC Loss=0.0000, IR Loss=0.0000, Ostrom Loss=0.0004, Resource Loss=0.0000, Policy Loss=2.7592
# --------------------------------------------------
# [Epoch 499, Episode 2]
# Inputs:
#  R=471.8820, M=524.4394, Z=-0.0135, mean_k=50.7368, mean_theta=1.0083
#  region_obs mean=-0.0323, std=0.8451
# Parameters (allocations):
#  c_alloc_mean=2.9865, x_alloc_mean=2.8813, l_alloc_mean=2.0041
#  c_alloc=2.9940, x_alloc=2.8809, l_alloc=2.0115
# Outputs:
#  Utility=1.2470
#  Total Loss=1.6198, VAE Loss=0.7451, IC Loss=0.5006, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=0.3739
# --------------------------------------------------
# [Epoch 500, Episode 1]
# Inputs:
#  R=472.5660, M=525.6893, Z=-0.0022, mean_k=50.6247, mean_theta=0.9222
#  region_obs mean=-0.0813, std=1.0059
# Parameters (allocations):
#  c_alloc_mean=2.9845, x_alloc_mean=2.8745, l_alloc_mean=2.0041
#  c_alloc=2.9892, x_alloc=2.8743, l_alloc=1.9994
# Outputs:
#  Utility=1.2517
#  Total Loss=-9.3858, VAE Loss=1.1495, IC Loss=0.2016, IR Loss=0.0000, Ostrom Loss=0.0002, Resource Loss=0.0000, Policy Loss=-10.7371
# --------------------------------------------------
# [Epoch 500, Episode 2]
# Inputs:
#  R=473.1077, M=523.2998, Z=0.0173, mean_k=50.5712, mean_theta=0.8266
#  region_obs mean=0.0720, std=0.9924
# Parameters (allocations):
#  c_alloc_mean=2.9833, x_alloc_mean=2.8908, l_alloc_mean=2.0041
#  c_alloc=2.9848, x_alloc=2.8860, l_alloc=2.0155
# Outputs:
#  Utility=1.0585
#  Total Loss=-4.8652, VAE Loss=1.1691, IC Loss=0.7231, IR Loss=0.0000, Ostrom Loss=0.0003, Resource Loss=0.0000, Policy Loss=-6.7576
# --------------------------------------------------
# Metrics saved to training_metrics.csv
# Enhanced logging data saved to CSV.
